# %% [markdown]
# ## 칼로리 소모 관련 가설 검증

# %% [markdown]
# ### 체중이 무거울 수록 칼로리 소모량이 높을까?

# %%
# 기본 통계
print(df[['Weight (kg)', 'Calories_Burned', 'Session_Duration (hours)']].describe().round(1))

# 칼로리 소모는 체중 뿐 아니라 운동시간과 유형에도 크게 영향을 받음
# 만약 운동시간이 길다면 칼로리 소모가 높아지는 건 당연하며, 이렇게 되면 체중 효과가 가려질 수 있음
# 따라서 체중 vs 칼로리 뿐만 아니라 영향을 줄 만한 다른 요인들(운동시간, 운동유형)과의 패턴을 확인해보고, 통제할 변수가 있다면 설정하기

# %% [markdown]
# ### 즉, 칼로리 소모량이 많을 수록 수분 섭취량이 높을까?

# %% [markdown]
# ## 체지방률 관련 가설 검증

# %% [markdown]
# ### Experience_Level이 높을 수록 Fat_Percentage가 낮을까? 즉, 운동 경험이 높을 수록 체지방률이 낮을까?
